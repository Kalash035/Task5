# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('C:\\Users\\91701\\Desktop\\python_ws\\heart.csv',encoding = 'cp1252')

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   60    1   3     145   233    1        0       150     0      2.3    0
# 1   35    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   55    1   1     120   236    0        1       178     0      0.8    2
# 4   56    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.tail()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 284   60    1   0     140   207    0        0       138     1      1.9    2
# 285   46    1   0     140   311    0        1       120     1      1.8    1
# 286   59    1   3     134   204    0        1       162     0      0.8    2
# 287   54    1   1     154   232    0        0       164     0      0.0    2
# 288   53    1   0     110   335    0        1       143     1      3.0    1
#
#      caa  thall  output
# 284    1      3       0
# 285    2      3       0
# 286    2      2       0
# 287    1      2       0
# 288    1      3       0

# %%
df.columns.values
# Out:
# array(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'], dtype=object)

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       289 non-null    int64
#  1   sex       289 non-null    int64
#  2   cp        289 non-null    int64
#  3   trtbps    289 non-null    int64
#  4   chol      289 non-null    int64
#  5   fbs       289 non-null    int64
#  6   restecg   289 non-null    int64
#  7   thalachh  289 non-null    int64
#  8   exng      289 non-null    int64
#  9   oldpeak   289 non-null    float64
#  10  slp       289 non-null    int64
#  11  caa       289 non-null    int64
#  12  thall     289 non-null    int64
#  13  output    289 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 31.7 KB

# %%
df.hist(bins = 50,grid = True, figsize=(20,15));

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  289.000000  289.000000  289.000000  289.000000  289.000000  289.000000
# mean    54.010381    0.678201    1.020761  131.377163  247.961938    0.145329
# std      9.132316    0.467977    1.027192   17.518432   51.596208    0.353043
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.000000    0.000000    0.000000  120.000000  212.000000    0.000000
# 50%     54.000000    1.000000    1.000000  130.000000  243.000000    0.000000
# 75%     60.000000    1.000000    2.000000  140.000000  276.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  289.000000  289.000000  289.000000  289.000000  289.000000  289.000000
# mean     0.515571  150.231834    0.318339    1.007612    1.418685    0.712803
# ...

# %%
Questions = [ "1. How  many people have diseases related to heart and how many don't? ",
              "2. Which sex has most heart disease?",
              "3. Which sex has which type of chest pain most?",
              "4. People with which chest pain are most pron to heart disease?",
              "5. Which sex has most cholestrol?",
              "6. Which sex has most cp?",
              "7. Which sex has most fbs?"]
Questions
# Out:
# ["1. How  many people have diseases related to heart and how many don't? ",
#  '2. Which sex has most heart disease?',
#  '3. Which sex has which type of chest pain most?',
#  '4. People with which chest pain are most pron to heart disease?',
#  '5. Which sex has most cholestrol?',
#  '6. Which sex has most cp?',
#  '7. Which sex has most fbs?']

# %%
df.output.value_counts()
# Out:
# output
# 1    165
# 0    124
# Name: count, dtype: int64

# %%
#bar chart
df.output.value_counts().plot(kind = 'bar' ,color =["red","green"])
plt.title("Heart Disease values")                            
plt.xlabel("1=Heart disease,0=No heart disease")                           
plt.ylabel("Amount");

# %%
df.output.value_counts().plot(kind = 'pie' ,figsize = (8,6))
plt.legend(["Disease","No disease"]);

# %%
df.sex.value_counts()
# Out:
# sex
# 1    196
# 0     93
# Name: count, dtype: int64

# %%
df.sex.value_counts().plot(kind = 'pie' ,figsize = (6,4))
plt.title('Male Female ratio')
plt.legend(["Male","Female"]);

# %%
pd.crosstab(df.output,df.sex)
# Out:
# sex      0    1
# output
# 0       21  103
# 1       72   93

# %%
 sns.countplot(x='output',data =df,hue='sex')
plt.title("Heart disease frequency for sex")
plt.xlabel("0=No heart Disease, 1= Heart Disease");

# %%
df.cp.value_counts().plot(kind='bar',color=['salmon','lightskyblue','springgreen','khaki'])
plt.title('Chest pain type vs count');

# %%
pd.crosstab(df.sex,df.cp)
# Out:
# cp    0   1   2   3
# sex
# 0    35  18  35   5
# 1    91  36  51  18

# %%
pd.crosstab(df.sex,df.cp).plot(kind='bar',color=['salmon','lightskyblue','springgreen','khaki'])
plt.title('Type of chest pain for sex')
plt.xlabel('0= Female, 1=Male');

# %%
 pd.crosstab(df.cp,df.output)
# Out:
# output   0   1
# cp
# 0       87  39
# 1       13  41
# 2       17  69
# 3        7  16

# %%
sns.countplot(x='cp',data =df,hue ='output')
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
sns.displot(x='age',data=df,bins=30,kde=True);

# %%
sns.displot(x='thalachh',data=df,bins=30,kde=True,color='blue');
